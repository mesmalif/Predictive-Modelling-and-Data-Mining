# %% [markdown]
# # <center> Week 2: Data Preparation </center>

# %% [markdown]
# ## Learning Objectives
#
# * What is data preparation?
# * How we can prepare data in Python?

# %% [markdown]
# [For online lab click here](https://mybinder.org/v2/gh/jupyterlab/jupyterlab-demo/master?urlpath=lab/tree/demo/Lorenz.ipynb)

# %% [markdown]
# ## Importing data
# <center> <img src="Figs/DataImport.PNG" height="150" width="300"> </center>
#
# #### 1- From files [(To learn more, click here)](https://www.py4e.com/lessons/files)
# #### 2- From database [(To learn more, click here)](https://www.py4e.com/lessons/json)
# #### 3- From Internet [(To learn more, click here)](https://www.py4e.com/lessons/servces)

# %% [markdown]
# ### Reading CSV files:

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('C:\\Users\\Esmal\\Desktop\\bigdata\\data\\US_Census.csv')

# %%
df.head(5)
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4      ...        0.5          1.3         1.8         26.5     23986
# 1     0.6      ...        1.0          1.4         3.9         26.4     85953
# 2     0.2      ...        1.8          1.5         1.6         24.1      8597
# 3     0.4      ...        0.6          1.5         0.7         28.8      8294
# 4     0.3      ...        0.9          0.4         2.3         34.9     22189
#
# ...

# %%
df.shape
# Out:
# (3220, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 37 columns):
# CensusId           3220 non-null int64
# State              3220 non-null object
# County             3220 non-null object
# TotalPop           3220 non-null int64
# Men                3220 non-null int64
# Women              3220 non-null int64
# Hispanic           3220 non-null float64
# White              3220 non-null float64
# Black              3220 non-null float64
# Native             3220 non-null float64
# Asian              3220 non-null float64
# Pacific            3220 non-null float64
# Citizen            3220 non-null int64
# Income             3219 non-null float64
# IncomeErr          3219 non-null float64
# IncomePerCap       3220 non-null int64
# IncomePerCapErr    3220 non-null int64
# Poverty            3220 non-null float64
# ChildPoverty       3219 non-null float64
# Professional       3220 non-null float64
# Service            3220 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# CensusId           0
# State              0
# County             0
# TotalPop           0
# Men                0
# Women              0
# Hispanic           0
# White              0
# Black              0
# Native             0
# Asian              0
# Pacific            0
# Citizen            0
# Income             1
# IncomeErr          1
# IncomePerCap       0
# IncomePerCapErr    0
# Poverty            0
# ChildPoverty       1
# Professional       0
# Service            0
# Office             0
# Construction       0
# Production         0
# Drive              0
# Carpool            0
# Transit            0
# Walk               0
# OtherTransp        0
# WorkAtHome         0
# MeanCommute        0
# Employed           0
# PrivateWork        0
# PublicWork         0
# SelfEmployed       0
# FamilyWork         0
# Unemployment       0
# dtype: int64

# %%
df.describe()
# Out:
#            CensusId      TotalPop           Men         Women     Hispanic  \
# count   3220.000000  3.220000e+03  3.220000e+03  3.220000e+03  3220.000000
# mean   31393.605280  9.940935e+04  4.889694e+04  5.051241e+04    11.011522
# std    16292.078954  3.193055e+05  1.566813e+05  1.626620e+05    19.241380
# min     1001.000000  8.500000e+01  4.200000e+01  4.300000e+01     0.000000
# 25%    19032.500000  1.121800e+04  5.637250e+03  5.572000e+03     1.900000
# 50%    30024.000000  2.603500e+04  1.293200e+04  1.305700e+04     3.900000
# 75%    46105.500000  6.643050e+04  3.299275e+04  3.348750e+04     9.825000
# max    72153.000000  1.003839e+07  4.945351e+06  5.093037e+06    99.900000
#
#              White        Black       Native        Asian      Pacific  \
# count  3220.000000  3220.000000  3220.000000  3220.000000  3220.000000
# mean     75.428789     8.665497     1.723509     1.229068     0.082733
# std      22.932890    14.279122     7.253115     2.633079     0.734931
# ...

# %% [markdown]
# ## Adding, dropping columns

# %% [markdown]
# **Add 1 to all rows of new column called 'Big Data'**

# %%
df['Big Data']=1

# %%
df.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native    ...     OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4    ...             1.3         1.8         26.5     23986
# 1     0.6    ...             1.4         3.9         26.4     85953
# 2     0.2    ...             1.5         1.6         24.1      8597
# 3     0.4    ...             1.5         0.7         28.8      8294
# 4     0.3    ...             0.4         2.3         34.9     22189
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  Big Data
# ...

# %% [markdown]
# **Drop columns 'Big Data' and 'Unemployment'**

# %%
df.columns
# Out:
# Index(['CensusId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen', 'Income',
#        'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment', 'Big Data'],
#       dtype='object')

# %%
df2=df.drop(['Unemployment','Big Data'], axis=1)

# %% [markdown]
# What columns do we have now? Why?

# %% [markdown]
# **Drop 3rd and 4th row**

# %%
df3=df.drop([2,3],axis=0)

# %% [markdown]
# Which rows do we have now? Why?

# %% [markdown]
# ## Data Visualization
#
# ![pairplot](Figs/seaborn_pairplot-1.png)
#
# * pd.df.Value_counts()
# * pd.df.describe()
# * pd.df.info()

# %% [markdown]
# ## Data Cleaning:
#
# ![DataCleaning](Figs/DataCleaning.PNG)
#
# * Checking data format
# * Handling missing data
# * Removing anomalies
