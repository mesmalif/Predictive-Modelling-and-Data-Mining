# %% [markdown]
# # <center> Week 2: Data Preparation </center>

# %% [markdown]
# ## Learning Objectives
#
# * What is data preparation?
# * How we can prepare data in Python?

# %% [markdown]
# [For online lab click here](https://mybinder.org/v2/gh/jupyterlab/jupyterlab-demo/master?urlpath=lab/tree/demo/Lorenz.ipynb)

# %% [markdown]
# ## Importing data
#
#
# ![dataloading](Figs/DataImport.PNG)
#
# #### 1- From files [(To learn more, click here)](https://www.py4e.com/lessons/files)
# #### 2- From database [(To learn more, click here)](https://www.py4e.com/lessons/json)
# #### 3- From Internet [(To learn more, click here).](https://www.py4e.com/lessons/servces) For more datasets [(Click here)](https://archive.ics.uci.edu/ml/datasets.html)

# %% [markdown]
# ### Reading CSV files:

# %%
import pandas as pd
import numpy as np

DFf=pd.read_table('C:\\Users\\Esmal\\Desktop\\bigdata\\data\\Adult.data',sep=',')

DFw=pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', sep=',')

# %%
DFf.head(5)
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %% [markdown]
# **Add header to the dataframe**
#
# - 1- Specify that there is no header in the original link by: **header=None**.
#
# - 2- Specify column names with a list of strings **(names=YourLIST)**.

# %%
HeadNames=['age', 'workclass', 'fnlwg', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 
           'race', 'sex','capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income' ]


DFw=pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', sep=',', header=None, names=HeadNames)


DFw.head()
# Out:
#    age          workclass   fnlwg   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
DFw.shape
# Out:
# (32561, 15)

# %%
DFw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwg             32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
DFw.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwg             0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
DFw.describe()
# Out:
#                 age         fnlwg  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ## Adding, dropping columns

# %% [markdown]
# **Add 1 to all rows of new column called 'Big Data'**

# %%
DFw['Big Data']=1

# %%
DFw.head()
# Out:
#    age          workclass   fnlwg   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income  \
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K
#
#    Big Data
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %% [markdown]
# **Drop columns 'Big Data' and 'capital-loss'**

# %%
DFw.columns
# Out:
# Index(['age', 'workclass', 'fnlwg', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income', 'Big Data'],
#       dtype='object')

# %%
DFw2=DFw.drop(['capital-loss','Big Data'], axis=1)

# %% [markdown]
# Which columns do we have now? Why?

# %% [markdown]
# **Drop 3rd and 4th row**

# %%
DFw3=DFw2.drop([2,3],axis=0)

# %% [markdown]
# Which rows do we have now? Why?

# %% [markdown]
# **Drop missing values** [[Ref.]](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html)

# %% [markdown]
# ### Filtering rows based on conditions
#
# **General format: df[ (condition1) * (condition2) ...]**
#
# **Example:** Create a new dataframe that only contains females older than 40 years old.

# %%
DFw3['sex'].value_counts()
# Out:
#  Male      21788
#  Female    10771
# Name: sex, dtype: int64

# %%
#Remove white space in dataframe

DFw3.replace(' ', '', inplace=True)    # What happens if we don't remove the white space?

# %%
DFw3[(DFw3['sex']=='Female') & (DFw3['age']>40)]    ## use DFw3['sex'][0] to make sure that
# Out:
#        age         workclass   fnlwg     education  education-num  \
# 6       49           Private  160187           9th              5
# 19      43  Self-emp-not-inc  292175       Masters             14
# 21      54           Private  302146       HS-grad              9
# 24      59           Private  109015       HS-grad              9
# 43      49           Private   94638       HS-grad              9
# 47      44           Private  128354       Masters             14
# 52      47           Private   51835   Prof-school             15
# 67      53           Private  169846       HS-grad              9
# 82      46           Private   51618       HS-grad              9
# 84      44           Private  343591       HS-grad              9
# 85      53           Private  346253       HS-grad              9
# 89      43       Federal-gov  410867     Doctorate             16
# 98      48           Private  171095    Assoc-acdm             12
# 102     47  Self-emp-not-inc  149116       Masters             14
# 125     47           Private  287828     Bachelors             13
# 134     46           Private  146195    Assoc-acdm             12
# 143     45           Private  196584     Assoc-voc             11
# 149     43                 ?  174662  Some-college             10
# 150     47         Local-gov  186009  Some-college             10
# 160     68                 ?   38317       1st-4th              2
# 162     44      Self-emp-inc   78374       Masters             14
# 169     66         Local-gov   54826     Assoc-voc             11
# 181     43           Private  114580  Some-college             10
# 186     41  Self-emp-not-inc  143129     Bachelors             13
# 187     53                 ?  135105     Bachelors             13
# 203     42         Local-gov  254817  Some-college             10
# 208     58      Self-emp-inc  210563       HS-grad              9
# 216     50           Private  313321    Assoc-acdm             12
# 224     53         Local-gov  140359     Preschool              1
# 226     60                 ?   24215          10th              6
# ...    ...               ...     ...           ...            ...
# 32386   59       Federal-gov   23789       HS-grad              9
# 32396   56           Private  135458       HS-grad              9
# 32397   41           Private  185660       HS-grad              9
# 32401   52         Local-gov  143533       7th-8th              4
# 32422   47           Private  161950       HS-grad              9
# 32423   61           Private   98776          11th              7
# 32427   41           Private  206878       HS-grad              9
# 32429   51         Local-gov  203334     Doctorate             16
# 32431   51           Private  274502       7th-8th              4
# 32445   61           Private  190682       HS-grad              9
# 32446   53           Private  158993       HS-grad              9
# 32454   50           Private  257933  Some-college             10
# 32460   62           Private  128092       HS-grad              9
# 32465   66           Private  269665       HS-grad              9
# 32469   58      Self-emp-inc  181974     Doctorate             16
# 32470   50           Private  485710     Doctorate             16
# 32473   41       Federal-gov  160467       Masters             14
# 32479   64         State-gov  222966       7th-8th              4
# 32481   52           Private  301229     Assoc-voc             11
# 32484   48           Private  268083  Some-college             10
# 32504   50           Private  208630       Masters             14
# 32508   45           Private  155093          10th              6
# 32513   46           Private   42972       Masters             14
# 32525   81                 ?  120478     Assoc-voc             11
# 32540   45         State-gov  252208       HS-grad              9
# 32541   41                 ?  202822       HS-grad              9
# 32543   45         Local-gov  119199    Assoc-acdm             12
# 32549   43         State-gov  255835  Some-college             10
# 32558   58           Private  151910       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation    relationship  \
# 6      Married-spouse-absent      Other-service   Not-in-family
# 19                  Divorced    Exec-managerial       Unmarried
# 21                 Separated      Other-service       Unmarried
# 24                  Divorced       Tech-support       Unmarried
# 43                 Separated       Adm-clerical       Unmarried
# 47                  Divorced    Exec-managerial       Unmarried
# 52        Married-civ-spouse     Prof-specialty            Wife
# 67        Married-civ-spouse       Adm-clerical            Wife
# 82        Married-civ-spouse      Other-service            Wife
# 84                  Divorced       Craft-repair   Not-in-family
# 85                  Divorced              Sales       Own-child
# 89             Never-married     Prof-specialty   Not-in-family
# 98                  Divorced    Exec-managerial       Unmarried
# 102            Never-married     Prof-specialty   Not-in-family
# 125       Married-civ-spouse    Exec-managerial            Wife
# 134                 Divorced       Tech-support   Not-in-family
# 143            Never-married     Prof-specialty   Not-in-family
# 149                 Divorced                  ?   Not-in-family
# 150                 Divorced       Adm-clerical       Unmarried
# 160                 Divorced                  ?   Not-in-family
# 162                 Divorced    Exec-managerial       Unmarried
# 169                  Widowed     Prof-specialty   Not-in-family
# 181                 Divorced       Adm-clerical   Not-in-family
# 186                 Divorced    Exec-managerial   Not-in-family
# 187                 Divorced                  ?   Not-in-family
# 203            Never-married     Prof-specialty   Not-in-family
# 208       Married-civ-spouse              Sales            Wife
# 216                 Divorced              Sales   Not-in-family
# 224            Never-married  Machine-op-inspct   Not-in-family
# 226                 Divorced                  ?   Not-in-family
# ...                      ...                ...             ...
# 32386     Married-civ-spouse              Sales            Wife
# 32396               Divorced       Tech-support   Not-in-family
# 32397              Separated       Adm-clerical       Unmarried
# 32401          Never-married      Other-service  Other-relative
# 32422               Divorced      Other-service       Unmarried
# 32423                Widowed  Handlers-cleaners   Not-in-family
# 32427               Divorced      Other-service       Unmarried
# 32429               Divorced    Exec-managerial   Not-in-family
# 32431               Divorced  Machine-op-inspct   Not-in-family
# 32445                Widowed       Craft-repair   Not-in-family
# 32446                Widowed  Machine-op-inspct       Unmarried
# 32454               Divorced       Adm-clerical   Not-in-family
# 32460                Widowed       Adm-clerical   Not-in-family
# 32465                Widowed    Exec-managerial   Not-in-family
# 32469          Never-married     Prof-specialty   Not-in-family
# 32470               Divorced     Prof-specialty   Not-in-family
# 32473               Divorced     Prof-specialty       Unmarried
# 32479     Married-civ-spouse      Other-service            Wife
# 32481              Separated              Sales       Unmarried
# 32484               Divorced    Exec-managerial   Not-in-family
# 32504               Divorced              Sales   Not-in-family
# 32508               Divorced      Other-service   Not-in-family
# 32513     Married-civ-spouse     Prof-specialty            Wife
# 32525               Divorced                  ?       Unmarried
# 32540              Separated       Adm-clerical       Own-child
# 32541              Separated                  ?   Not-in-family
# 32543               Divorced     Prof-specialty       Unmarried
# 32549               Divorced       Adm-clerical  Other-relative
# 32558                Widowed       Adm-clerical       Unmarried
# 32560     Married-civ-spouse    Exec-managerial            Wife
#
#                      race     sex  capital-gain  hours-per-week  \
# 6                   Black  Female             0              16
# 19                  White  Female             0              45
# 21                  Black  Female             0              20
# 24                  White  Female             0              40
# 43                  White  Female             0              40
# 47                  White  Female             0              40
# 52                  White  Female             0              60
# 67                  White  Female             0              40
# 82                  White  Female             0              40
# 84                  White  Female         14344              40
# 85                  White  Female             0              35
# 89                  White  Female             0              50
# 98                  White  Female             0              40
# 102                 White  Female             0              50
# 125                 White  Female             0              40
# 134                 Black  Female             0              36
# 143                 White  Female             0              40
# 149                 White  Female             0              40
# 150                 White  Female             0              38
# 160                 White  Female             0              20
# 162    Asian-Pac-Islander  Female             0              40
# 169                 White  Female             0              20
# 181                 White  Female             0              40
# 186                 White  Female             0              40
# 187                 White  Female             0              50
# 203                 White  Female             0              40
# 208                 White  Female         15024              35
# 216                 White  Female             0              40
# 224                 White  Female             0              35
# 226    Amer-Indian-Eskimo  Female             0              10
# ...                   ...     ...           ...             ...
# 32386               White  Female             0              40
# 32396               Black  Female             0              40
# 32397               White  Female             0              40
# 32401               Black  Female             0              40
# 32422               White  Female             0              32
# 32423               White  Female             0              30
# 32427               White  Female             0              32
# 32429               White  Female             0              45
# 32431               White  Female             0              48
# 32445               Black  Female             0              50
# 32446               Black  Female             0              38
# 32454               White  Female             0              40
# 32460               White  Female             0              32
# 32465               White  Female             0              25
# 32469               White  Female             0              99
# 32470               White  Female             0              50
# 32473               White  Female          1506              40
# 32479               Black  Female             0              40
# 32481               White  Female             0              40
# 32484               White  Female             0              40
# 32504               White  Female             0              50
# 32508               Black  Female             0              38
# 32513               White  Female             0              22
# 32525               White  Female             0               1
# 32540               White  Female             0              40
# 32541               Black  Female             0              32
# 32543               White  Female             0              48
# 32549               White  Female             0              40
# 32558               White  Female             0              40
# 32560               White  Female         15024              40
#
#            native-country income
# 6                 Jamaica  <=50K
# 19          United-States   >50K
# 21          United-States  <=50K
# 24          United-States  <=50K
# 43          United-States  <=50K
# 47          United-States  <=50K
# 52               Honduras   >50K
# 67          United-States   >50K
# 82          United-States  <=50K
# 84          United-States   >50K
# 85          United-States  <=50K
# 89          United-States   >50K
# 98                England  <=50K
# 102         United-States  <=50K
# 125         United-States   >50K
# 134         United-States  <=50K
# 143         United-States   >50K
# 149         United-States  <=50K
# 150                Mexico  <=50K
# 160         United-States  <=50K
# 162         United-States  <=50K
# 169         United-States  <=50K
# 181         United-States  <=50K
# 186         United-States  <=50K
# 187         United-States  <=50K
# 203         United-States  <=50K
# 208         United-States   >50K
# 216         United-States  <=50K
# 224         United-States  <=50K
# 226         United-States  <=50K
# ...                   ...    ...
# 32386       United-States   >50K
# 32396       United-States  <=50K
# 32397       United-States  <=50K
# 32401       United-States  <=50K
# 32422       United-States  <=50K
# 32423       United-States  <=50K
# 32427       United-States  <=50K
# 32429       United-States   >50K
# 32431       United-States  <=50K
# 32445       United-States  <=50K
# 32446       United-States  <=50K
# 32454       United-States  <=50K
# 32460       United-States  <=50K
# 32465       United-States  <=50K
# 32469                   ?  <=50K
# 32470       United-States  <=50K
# 32473       United-States  <=50K
# 32479       United-States  <=50K
# 32481       United-States  <=50K
# 32484       United-States  <=50K
# 32504       United-States   >50K
# 32508  Dominican-Republic  <=50K
# 32513       United-States   >50K
# 32525                   ?  <=50K
# 32540       United-States  <=50K
# 32541       United-States  <=50K
# 32543       United-States  <=50K
# 32549       United-States  <=50K
# 32558       United-States  <=50K
# 32560       United-States   >50K
#
# [3946 rows x 14 columns]

# %% [markdown]
# **Example:** Which "workclass" makes more than 50k?

# %%
DFw3[DFw3['income']== ">50K"].workclass.value_counts()  #Other usefull inputs to value_counts:  normalize=True, dropna=False
# Out:
# Private             4963
# Self-emp-not-inc     724
# Self-emp-inc         622
# Local-gov            617
# Federal-gov          371
# State-gov            353
# ?                    191
# Name: workclass, dtype: int64

# %% [markdown]
# ## Data Visualization
#
# ![pairplot](Figs/seaborn_pairplot-1.png)
#
# * pd.df.Value_counts()
# * pd.df.describe()
# * pd.df.info()

# %% [markdown]
# ## Data Cleaning:
#
# ![DataCleaning](Figs/DataCleaning.PNG)
#
# * Checking data format
# * Handling missing data
# * Removing anomalies
